# %%
load('https://raw.githubusercontent.com/cerickson30/qBound/main/spectator_floor_display_functions.py')

# %% [markdown]
# If you're going to go through many graphs, you can first load the full spectator floor dictionary by using
# <pre>uspcm_dict = get_full_uspcm_dict()
# </pre>
# and then passing it in as an argument to the find_minimal_representation() function.
#
# The find_minimal_representation() function accepts a graph as a Graph object, an adjacency matrix, or a graph6_string and determines if that graph is minor-minimal with respect to the spectator floor number, and if it is not minor-minimal, the function will find a minor of the graph which is minor-minimal with respect to the spectator floor number.

# %%
find_minimal_representation?
# Out:
# Signature:      find_minimal_representation(graph, uspcm_dict=None, minimals_dict=None)
# Docstring:
# INPUT: graph: A graph, graph6_string, or adjacency matrix for a
# connected graph on at most 10 vertices uspcm_dict: A dictionary of
# spectator floor numbers, either the complete dictionary or partial
# dictionary with the spectator floor numbers for graphs on the number
# of vertices and edges that the graph argument has. OUTPUT: The
# spectator floor number of the graph.
# Init docstring: Initialize self.  See help(type(self)) for accurate signature.
# File:           ~/.sage/temp/lambda/40017/tmp_ue7x2jn0.py
# Type:           function

# %%
find_minimal_representation(graphs.CompleteGraph(8))
# Out:
# GHQ}vo is a minor of Complete graph, both have spectator floor of 6, so Complete graph is NOT minor-minimal
# Graphics Array of size 1 x 2
# 'GHQ}vo'

# %%
find_minimal_representation(graphs.PetersenGraph())
# Out:
# Petersen graph is minor-minimal, the canonical labelling of Petersen graph has graph6_string of I@OZCMgs?
# Graphics object consisting of 26 graphics primitives
# 'I@OZCMgs?'

# %%
G = graphs.CycleGraph(7)
G.complement()
# Out:
# complement(Cycle graph): Graph on 7 vertices

# %%
find_minimal_representation(G.complement())
# Out:
# F_|tg is a minor of complement(Cycle graph), both have spectator floor of 5, so complement(Cycle graph) is NOT minor-minimal
# Graphics Array of size 1 x 2
# 'F_|tg'
